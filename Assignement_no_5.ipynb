# %% [markdown]
# # Practical 5
#
# ## LSTM-Based AI Agent for Sequence Prediction
#
#
#
# ### Title
#
# **Text Prediction System using LSTM with FastAPI Deployment**
#
#
#
# ### Group Members
#
# * Aditi Namde
# * Sujal Sonawane
# * Shivam Khedkar
# * Manoj Ghadage
#
#
#
# ### Objective
#
# To build an LSTM-based sequence prediction model for next-word prediction and deploy it using FastAPI to create an end-to-end AI system.
#
#
#
# ###  Methodology
#
# * Dataset Collection (Shakespeare Text Dataset)
# * Text Preprocessing (Tokenization, Sequence Generation, Padding)
# * LSTM Model Development
# * Model Training and Prediction
# * Deployment using FastAPI
# * Testing using Swagger UI
#
#
#
# ### Deployment Approach
#
# The trained LSTM model is deployed using FastAPI, where a REST API endpoint (`/predict`) is created. The user provides input text, and the system predicts the next word based on learned sequence patterns.
#
#
#
# ### Outcome
#
# The system successfully predicts the next word for a given input sequence and demonstrates a complete AI pipeline including model training, deployment, and testing.
#
#
#
# ### AI Tool Acknowledgement
#
# Tool Used: ChatGPT
# Purpose: Assistance in code debugging, deployment setup, and conceptual understanding of LSTM and FastAPI
# Sections Used: API deployment

# %% [markdown]
# **Github Repository:**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle

# %%
print("Loading dataset...")

url = "https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt"
file_path = tf.keras.utils.get_file('data.txt', url)

with open(file_path, 'r', encoding='utf-8') as f:
    raw_text = f.read()

# Split into lines
lines = raw_text.lower().split('\n')

# Take first 1500 lines (changed from 2000)
corpus = [line for line in lines if line.strip() != ""][:1500]

print("Total lines used:", len(corpus))
# Out:
# Loading dataset...
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# 1115394/1115394 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Total lines used: 1500

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words)
# Out:
# Vocabulary size: 2059

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words)
# Out:
# Vocabulary size: 2059

# %%
sequences = []

for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram = token_list[:i+1]
        sequences.append(n_gram)

# %%
max_len = max([len(x) for x in sequences])

sequences = np.array(pad_sequences(sequences, maxlen=max_len, padding='pre'))

X = sequences[:, :-1]
y = sequences[:, -1]

y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
model = Sequential()

model.add(Embedding(total_words, 64, input_length=max_len-1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model = Sequential()

model.add(Embedding(total_words, 64, input_length=max_len-1))  # changed 50 → 64
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.save("lstm_text_model.keras")

config = {
    'tokenizer': tokenizer,
    'max_len': max_len
}

with open('config.pkl', 'wb') as f:
    pickle.dump(config, f)

print("Model saved successfully!")
# Out:
# Model saved successfully!
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)

# %%
def predict_word(model, tokenizer, text, max_len):
    token_list = tokenizer.texts_to_sequences([text])[0]
    token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')

    pred = model.predict(token_list, verbose=0)
    index = np.argmax(pred)

    for word, idx in tokenizer.word_index.items():
        if idx == index:
            return word

    return ""

# %%
input_text = "to be or not to"
print("Input:", input_text)

next_word = predict_word(model, tokenizer, input_text, max_len)
print("Predicted word:", next_word)
# Out:
# Input: to be or not to
# Predicted word: holding

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import tensorflow as tf
import pickle
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

app = FastAPI()

# Load model
model = tf.keras.models.load_model('lstm_text_model.keras')

with open('config.pkl', 'rb') as f:
    config = pickle.load(f)

tokenizer = config['tokenizer']
max_len = config['max_len']

class InputText(BaseModel):
    text: str

@app.post("/predict")
def predict(data: InputText):
    token_list = tokenizer.texts_to_sequences([data.text])[0]
    token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')

    pred = model.predict(token_list, verbose=0)
    index = np.argmax(pred)

    word = ""
    for w, i in tokenizer.word_index.items():
        if i == index:
            word = w
            break

    return {"input": data.text, "next_word": word}

# %%
model.fit(X, y, epochs=1)
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.0400 - loss: 6.7398

# %%
model.save_weights("model.weights.h5")

# %%
from google.colab import files
files.download("model.weights.h5")

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3)

history = model.fit(
    X, y,
    epochs=50,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0429 - loss: 6.2674
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.0459 - loss: 6.1609
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.0513 - loss: 6.0670
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.0517 - loss: 5.9848
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0520 - loss: 5.9062
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0539 - loss: 5.8280
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.0584 - loss: 5.7452
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0619 - loss: 5.6597
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0656 - loss: 5.5687
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0749 - loss: 5.4702
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0780 - loss: 5.3701
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0822 - loss: 5.2706
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.0932 - loss: 5.1715
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0952 - loss: 5.0708
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.0994 - loss: 4.9739
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.1074 - loss: 4.8773
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.1119 - loss: 4.7762
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.1224 - loss: 4.6775
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.1267 - loss: 4.5738
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.1357 - loss: 4.4712
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1446 - loss: 4.3692
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.1537 - loss: 4.2675
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.1632 - loss: 4.1660
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.1796 - loss: 4.0643
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.1936 - loss: 3.9607
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.2096 - loss: 3.8585
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.2242 - loss: 3.7555
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.2461 - loss: 3.6512
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.2607 - loss: 3.5529
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2821 - loss: 3.4525
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.3045 - loss: 3.3523
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.3286 - loss: 3.2551
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.3454 - loss: 3.1597
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.3684 - loss: 3.0647
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.3865 - loss: 2.9739
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.4042 - loss: 2.8848
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.4178 - loss: 2.7996
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4332 - loss: 2.7175
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4537 - loss: 2.6365
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.4617 - loss: 2.5599
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4785 - loss: 2.4881
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4918 - loss: 2.4163
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.5031 - loss: 2.3487
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.5174 - loss: 2.2813
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.5257 - loss: 2.2194
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.5391 - loss: 2.1558
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5532 - loss: 2.0969
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.5637 - loss: 2.0397
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5751 - loss: 1.9833
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.5843 - loss: 1.9317

# %%
model.save_weights("model.weights.h5")

# %%
from google.colab import files
files.download("model.weights.h5")
